# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("biodeg.csv",delimiter=';',header=None)
df.columns = ['SPMAX_L', 'J_DZ(E)', 'NHM', 'F01[N-N]', 'F04[C-N]', 'NSSSSC', 'NCB-', 'C%', 'NCP', 'NO', 'F03[C-N]', 'SDSSC', 'HYWI_B(M)', 'LOC', 'SM6_L', 'F03[C-O]', 'ME', 'MI', 'NN-N', 'NARNO2', 'NCRX3', 'SPPOSA_B(P)', 'NCIR', 'B01[C-BR]', 'B03[C-CL]', 'N-073', 'SPMAX_A', 'PSI_I_1D', 'B04[C-BR]', 'SDO', 'TI2_L', 'NCRT', 'C-026', 'F02[C-N]', 'NHDON', 'SPMAX_B(M)', 'PSI_I_A', 'NN', 'SM6_B(M)', 'NARCOOR', 'NX', 'EXPERIMENTAL CLASS']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv("biodeg.csv",delimiter=';',header=None)
#       2 df.columns = ['SPMAX_L', 'J_DZ(E)', 'NHM', 'F01[N-N]', 'F04[C-N]', 'NSSSSC', 'NCB-', 'C%', 'NCP', 'NO', 'F03[C-N]', 'SDSSC', 'HYWI_B(M)', 'LOC', 'SM6_L', 'F03[C-O]', 'ME', 'MI', 'NN-N', 'NARNO2', 'NCRX3', 'SPPOSA_B(P)', 'NCIR', 'B01[C-BR]', 'B03[C-CL]', 'N-073', 'SPMAX_A', 'PSI_I_1D', 'B04[C-BR]', 'SDO', 'TI2_L', 'NCRT', 'C-026', 'F02[C-N]', 'NHDON', 'SPMAX_B(M)', 'PSI_I_A', 'NN', 'SM6_B(M)', 'NARCOOR', 'NX', 'EXPERIMENTAL CLASS']
#
# NameError: name 'pd' is not defined

# %%
df
# Out:
#       SPMAX_L  J_DZ(E)  NHM  F01[N-N]  F04[C-N]  NSSSSC  NCB-    C%  NCP  NO
# 0       3.919   2.6909    0         0         0       0     0  31.4    2   0  \
# 1       4.170   2.1144    0         0         0       0     0  30.8    1   1
# 2       3.932   3.2512    0         0         0       0     0  26.7    2   4
# 3       3.000   2.7098    0         0         0       0     0  20.0    0   2
# 4       4.236   3.3944    0         0         0       0     0  29.4    2   4
# ...       ...      ...  ...       ...       ...     ...   ...   ...  ...  ..
# 1050    5.431   2.8955    0         0         0       2     0  32.1    4   1
# 1051    5.287   3.3732    0         0         9       0     0  35.3    0   9
# 1052    4.869   1.7670    0         1         9       0     5  44.4    0   4
# 1053    5.158   1.6914    2         0        36       0     9  56.1    0   0
# 1054    5.076   2.6588    2         0         0       0     4  54.5    0   0
#
# ...

# %%
df.isna().sum()
# Out:
# SPMAX_L               0
# J_DZ(E)               0
# NHM                   0
# F01[N-N]              0
# F04[C-N]              0
# NSSSSC                0
# NCB-                  0
# C%                    0
# NCP                   0
# NO                    0
# F03[C-N]              0
# SDSSC                 0
# HYWI_B(M)             0
# LOC                   0
# SM6_L                 0
# F03[C-O]              0
# ME                    0
# MI                    0
# NN-N                  0
# NARNO2                0
# NCRX3                 0
# SPPOSA_B(P)           0
# NCIR                  0
# B01[C-BR]             0
# B03[C-CL]             0
# N-073                 0
# SPMAX_A               0
# PSI_I_1D              0
# B04[C-BR]             0
# SDO                   0
# TI2_L                 0
# NCRT                  0
# C-026                 0
# F02[C-N]              0
# NHDON                 0
# SPMAX_B(M)            0
# PSI_I_A               0
# NN                    0
# ...

# %%
df['EXPERIMENTAL CLASS'].unique()
# Out:
# array(['RB', 'NRB'], dtype=object)

# %%
dic = {"RB":1,"NRB":0}

# %%
df['EXPERIMENTAL CLASS'] = df["EXPERIMENTAL CLASS"].map(dic)

# %%
df
# Out:
#       SPMAX_L  J_DZ(E)  NHM  F01[N-N]  F04[C-N]  NSSSSC  NCB-    C%  NCP  NO
# 0       3.919   2.6909    0         0         0       0     0  31.4    2   0  \
# 1       4.170   2.1144    0         0         0       0     0  30.8    1   1
# 2       3.932   3.2512    0         0         0       0     0  26.7    2   4
# 3       3.000   2.7098    0         0         0       0     0  20.0    0   2
# 4       4.236   3.3944    0         0         0       0     0  29.4    2   4
# ...       ...      ...  ...       ...       ...     ...   ...   ...  ...  ..
# 1050    5.431   2.8955    0         0         0       2     0  32.1    4   1
# 1051    5.287   3.3732    0         0         9       0     0  35.3    0   9
# 1052    4.869   1.7670    0         1         9       0     5  44.4    0   4
# 1053    5.158   1.6914    2         0        36       0     9  56.1    0   0
# 1054    5.076   2.6588    2         0         0       0     4  54.5    0   0
#
# ...

# %%
y = df['EXPERIMENTAL CLASS']
x = df.drop('EXPERIMENTAL CLASS',axis = 1)

# %%
x
# Out:
#       SPMAX_L  J_DZ(E)  NHM  F01[N-N]  F04[C-N]  NSSSSC  NCB-    C%  NCP  NO
# 0       3.919   2.6909    0         0         0       0     0  31.4    2   0  \
# 1       4.170   2.1144    0         0         0       0     0  30.8    1   1
# 2       3.932   3.2512    0         0         0       0     0  26.7    2   4
# 3       3.000   2.7098    0         0         0       0     0  20.0    0   2
# 4       4.236   3.3944    0         0         0       0     0  29.4    2   4
# ...       ...      ...  ...       ...       ...     ...   ...   ...  ...  ..
# 1050    5.431   2.8955    0         0         0       2     0  32.1    4   1
# 1051    5.287   3.3732    0         0         9       0     0  35.3    0   9
# 1052    4.869   1.7670    0         1         9       0     5  44.4    0   4
# 1053    5.158   1.6914    2         0        36       0     9  56.1    0   0
# 1054    5.076   2.6588    2         0         0       0     4  54.5    0   0
#
# ...

# %%
y = np.array(y)

# %%
np.unique(y)
# Out:
# array([0, 1], dtype=int64)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state = 0)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (738, 41)
# (317, 41)
# (738,)
# (317,)

# %%
from sklearn.preprocessing import StandardScaler

# %%
# lr = LogisticRegression()
# lr.fit(x_train,y_train)
# train_pred = lr.predict(x_train)
# test_pred = lr.predict(x_test)
# from sklearn.metrics import accuracy_score
# train_acc=accuracy_score(y_train,train_pred)
# test_acc=accuracy_score(y_test, test_pred)

# print(test_acc)
# print(train_acc)

# %%
scaler = StandardScaler()

# %%
scaled_x_train = scaler.fit_transform(x_train)
scaled_x_test = scaler.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_model = LogisticRegression()
log_model.fit(scaled_x_train,y_train)
# Out:
# LogisticRegression()

# %%
log_model.coef_
# Out:
# array([[-0.48608954, -0.71755975, -0.63942906, -0.55496891, -0.56698326,
#         -1.08664426, -1.73385358,  1.35415268,  0.07734192,  0.84296554,
#          0.0964441 ,  0.27010099, -1.05339457,  1.02918678,  0.38777815,
#         -0.63700161,  0.1144646 ,  0.08431388, -0.30309437, -0.75438951,
#         -0.38489228, -0.11139881,  0.01527487, -0.15190176, -0.33125926,
#          0.39621656,  0.06742206,  0.03684175,  0.33929699,  0.69092565,
#         -0.01518229, -0.95111376,  0.16916226, -0.98355912,  0.44787319,
#          0.14348531,  0.86063577, -0.46364244, -0.59265053,  0.42850098,
#         -0.15790772]])

# %%
from sklearn.metrics import accuracy_score

# %%
y_pred = log_model.predict(scaled_x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8580441640378549

# %%
akshat
# Out:
#         Segment  Head_m1_x  Head_m1_y  Head_m1_z  L_arm_m2_x  L_arm_m2_y
# 0             0    990.628    176.897   1677.520     580.044     141.815  \
# 1             1    987.955    177.343   1677.172     580.044     141.815
# 2             2    987.955    177.343   1677.172     579.995     142.032
# 3             3    987.955    177.343   1677.172     579.995     142.032
# 4             4    987.955    177.343   1677.172     579.995     142.032
# ...         ...        ...        ...        ...         ...         ...
# 605376     2194    422.173   -138.014   1765.077     392.432    -377.394
# 605377     2195    422.173   -138.032   1765.124     392.432    -377.394
# 605378     2196    422.173   -138.032   1765.124     392.432    -377.394
# 605379     2197    422.173   -138.032   1765.124     392.450    -377.331
# 605380     2198    422.173   -138.032   1765.124     392.450    -377.331
#
#         L_arm_m2_z  L_arm_m3_x  L_arm_m3_y  L_arm_m3_z  ...  L_leg_m7_z
# ...

# %%
akshat.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 605381 entries, 0 to 605380
# Data columns (total 31 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Segment     605381 non-null  int64
#  1   Head_m1_x   605381 non-null  float64
#  2   Head_m1_y   605381 non-null  float64
#  3   Head_m1_z   605381 non-null  float64
#  4   L_arm_m2_x  605381 non-null  float64
#  5   L_arm_m2_y  605381 non-null  float64
#  6   L_arm_m2_z  605381 non-null  float64
#  7   L_arm_m3_x  605381 non-null  float64
#  8   L_arm_m3_y  605381 non-null  float64
#  9   L_arm_m3_z  605381 non-null  float64
#  10  R_arm_m4_x  605381 non-null  float64
#  11  R_arm_m4_y  605381 non-null  float64
#  12  R_arm_m4_z  605381 non-null  float64
#  13  R_arm_m5_x  605381 non-null  float64
#  14  R_arm_m5_y  605381 non-null  float64
#  15  R_arm_m5_z  605381 non-null  float64
#  16  L_leg_m6_x  605381 non-null  float64
#  17  L_leg_m6_y  605381 non-null  float64
# ...
